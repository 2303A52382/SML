# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Reading data

# %%
d=pd.read_csv('/content/magic gamma telescope.csv')
d
# Out:
#        Unnamed: 0   fLength    fWidth   fSize   fConc  fConc1     fAsym  \
# 0               0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004
# 1               1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722
# 2               2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410
# 3               3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107
# 4               4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277
# ...           ...       ...       ...     ...     ...     ...       ...
# 19015       19015   21.3846   10.9170  2.6161  0.5857  0.3934   15.2618
# 19016       19016   28.9452    6.7020  2.2672  0.5351  0.2784   37.0816
# 19017       19017   75.4455   47.5305  3.4483  0.1417  0.0549   -9.3561
# 19018       19018  120.5135   76.9018  3.9939  0.0944  0.0683    5.8043
# 19019       19019  187.1814   53.0014  3.2093  0.2876  0.1539 -167.3125
#
#         fM3Long  fM3Trans   fAlpha     fDist class
# 0       22.0110   -8.2027  40.0920   81.8828     g
# ...

# %% [markdown]
# Checking for null values

# %%
d.isnull()
# Out:
#        Unnamed: 0  fLength  fWidth  fSize  fConc  fConc1  fAsym  fM3Long  \
# 0           False    False   False  False  False   False  False    False
# 1           False    False   False  False  False   False  False    False
# 2           False    False   False  False  False   False  False    False
# 3           False    False   False  False  False   False  False    False
# 4           False    False   False  False  False   False  False    False
# ...           ...      ...     ...    ...    ...     ...    ...      ...
# 19015       False    False   False  False  False   False  False    False
# 19016       False    False   False  False  False   False  False    False
# 19017       False    False   False  False  False   False  False    False
# 19018       False    False   False  False  False   False  False    False
# 19019       False    False   False  False  False   False  False    False
#
#        fM3Trans  fAlpha  fDist  class
# 0         False   False  False  False
# ...

# %% [markdown]
# String to integer

# %%
mapping={"g":1,"h":2}
d['class']=d['class'].map(mapping)
print(d)
# Out:
#        Unnamed: 0   fLength    fWidth   fSize   fConc  fConc1     fAsym  \
# 0               0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004
# 1               1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722
# 2               2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410
# 3               3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107
# 4               4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277
# ...           ...       ...       ...     ...     ...     ...       ...
# 19015       19015   21.3846   10.9170  2.6161  0.5857  0.3934   15.2618
# 19016       19016   28.9452    6.7020  2.2672  0.5351  0.2784   37.0816
# 19017       19017   75.4455   47.5305  3.4483  0.1417  0.0549   -9.3561
# 19018       19018  120.5135   76.9018  3.9939  0.0944  0.0683    5.8043
# 19019       19019  187.1814   53.0014  3.2093  0.2876  0.1539 -167.3125
#
#         fM3Long  fM3Trans   fAlpha     fDist  class
# ...

# %% [markdown]
# Target variable

# %%
y=d['class']
print(y)
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 19015    2
# 19016    2
# 19017    2
# 19018    2
# 19019    2
# Name: class, Length: 19020, dtype: int64

# %% [markdown]
# Features

# %%
x=d.drop(['class'],axis=1)
print(x)
# Out:
#        Unnamed: 0   fLength    fWidth   fSize   fConc  fConc1     fAsym  \
# 0               0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004
# 1               1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722
# 2               2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410
# 3               3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107
# 4               4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277
# ...           ...       ...       ...     ...     ...     ...       ...
# 19015       19015   21.3846   10.9170  2.6161  0.5857  0.3934   15.2618
# 19016       19016   28.9452    6.7020  2.2672  0.5351  0.2784   37.0816
# 19017       19017   75.4455   47.5305  3.4483  0.1417  0.0549   -9.3561
# 19018       19018  120.5135   76.9018  3.9939  0.0944  0.0683    5.8043
# 19019       19019  187.1814   53.0014  3.2093  0.2876  0.1539 -167.3125
#
#         fM3Long  fM3Trans   fAlpha     fDist
# 0       22.0110   -8.2027  40.0920   81.8828
# ...

# %% [markdown]
# normalization

# %%
dd1=(x-x.min())/(x.max()-x.min())
dd1
# Out:
#        Unnamed: 0   fLength    fWidth     fSize     fConc    fConc1     fAsym  \
# 0        0.000000  0.074306  0.062415  0.208043  0.430390  0.293229  0.470032
# 1        0.000053  0.082815  0.045727  0.170668  0.587794  0.558601  0.468649
# 2        0.000105  0.478241  0.530579  0.626818  0.027617  0.027263  0.556215
# 3        0.000158  0.059212  0.037338  0.117445  0.683714  0.580679  0.469558
# 4        0.000210  0.214774  0.120603  0.360674  0.345153  0.271003  0.437870
# ...           ...       ...       ...       ...       ...       ...       ...
# 19015    0.999790  0.051838  0.042581  0.199527  0.650756  0.582457  0.457992
# 19016    0.999842  0.074757  0.026141  0.096363  0.593249  0.412061  0.479112
# 19017    0.999895  0.215712  0.185389  0.445594  0.146153  0.080901  0.434164
# 19018    0.999947  0.352326  0.299950  0.606919  0.092397  0.100756  0.448838
# 19019    1.000000  0.554415  0.206728  0.374926  0.311967  0.227589  0.281277
#
# ...

# %% [markdown]
# train_test_split

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y,
test_size=0.2, random_state=42)
x_train
# Out:
#        Unnamed: 0  fLength   fWidth   fSize   fConc  fConc1    fAsym  fM3Long  \
# 2499         2499  30.3038  10.7505  2.5205  0.4284  0.2730  -0.3839 -12.6961
# 7958         7958  25.1106  12.9009  2.4472  0.4714  0.2589  21.5544   8.8261
# 7664         7664  24.0236  15.8415  2.5746  0.4154  0.2463  19.9012  -7.7529
# 218           218  46.5588  28.6929  3.3971  0.1864  0.0996  17.6816  46.0987
# 14575       14575  15.1501  14.8593  2.2314  0.7604  0.3815  21.3058  -3.0300
# ...           ...      ...      ...     ...     ...     ...      ...      ...
# 11284       11284  31.9212  16.7667  2.6566  0.3837  0.2348   3.7913  21.0170
# 11964       11964  43.4538  17.6541  2.9965  0.2621  0.1426 -12.4850 -23.2863
# 5390         5390  19.9926  12.0866  2.4354  0.5725  0.3982  16.1410  16.3239
# 860           860  31.4336  23.2651  2.9340  0.2957  0.1717  -9.1278  19.8518
# 15795       15795  50.8745  10.5763  2.5244  0.3663  0.1858  63.2724  45.5987
#
# ...

# %%
x_test
# Out:
#        Unnamed: 0   fLength   fWidth   fSize   fConc  fConc1    fAsym  \
# 18749       18749   48.0573  11.0862  2.9571  0.3620  0.1882   0.4200
# 7051         7051   23.4858   0.0000  2.2393  0.7378  0.3775  -2.9397
# 10901       10901   40.5429  19.4073  3.3382  0.2369  0.1269  29.1908
# 15858       15858   16.6123   7.8423  2.5572  0.5829  0.3371   6.7271
# 17968       17968  205.4250  37.7936  3.2727  0.2167  0.1257  46.0952
# ...           ...       ...      ...     ...     ...     ...      ...
# 8138         8138   12.9935  11.0298  2.3149  0.7506  0.4479 -14.2100
# 10263       10263   44.8332  10.5008  2.7067  0.4656  0.2485   3.4712
# 3289         3289   29.1486  16.3655  2.7756  0.3755  0.2054  -9.5722
# 9384         9384   27.5346  17.1474  2.6637  0.3384  0.1746  -6.5985
# 16051       16051   34.0466  10.7681  2.7645  0.4592  0.2709  13.5489
#
#         fM3Long  fM3Trans   fAlpha     fDist
# 18749   32.4358   -2.2992  26.9300  165.2240
# ...

# %%
y_test
# Out:
# 18749    2
# 7051     1
# 10901    1
# 15858    2
# 17968    2
#         ..
# 8138     1
# 10263    1
# 3289     1
# 9384     1
# 16051    2
# Name: class, Length: 3804, dtype: int64

# %%
y_train
# Out:
# 2499     1
# 7958     1
# 7664     1
# 218      1
# 14575    2
#         ..
# 11284    1
# 11964    1
# 5390     1
# 860      1
# 15795    2
# Name: class, Length: 15216, dtype: int64

# %% [markdown]
# SVM classification

# %%
from sklearn.svm import SVC
lr=SVC()
m=lr.fit(x_train,y_train)
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
yp=m.predict(x_test)
print(accuracy_score(y_test,yp))
# Out:
# 0.9997371188222923

# %%
print(classification_report(y_test,yp))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      2460
#            2       1.00      1.00      1.00      1344
#
#     accuracy                           1.00      3804
#    macro avg       1.00      1.00      1.00      3804
# weighted avg       1.00      1.00      1.00      3804

# %%
print(confusion_matrix(y_test,yp))
# Out:
# [[2460    0]
#  [   1 1343]]

# %% [markdown]
# perceptron

# %%
from sklearn.linear_model import Perceptron
lr1=Perceptron()
m=lr1.fit(x_train,y_train)

yp1=m.predict(x_test)
print(accuracy_score(y_test,yp1))
# Out:
# 0.6474763406940063

# %%
print(confusion_matrix(y_test,yp1))
# Out:
# [[1119 1341]
#  [   0 1344]]

# %%
print(classification_report(y_test,yp1))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      0.45      0.63      2460
#            2       0.50      1.00      0.67      1344
#
#     accuracy                           0.65      3804
#    macro avg       0.75      0.73      0.65      3804
# weighted avg       0.82      0.65      0.64      3804

# %% [markdown]
# logistic regression

# %%
from sklearn.linear_model import LogisticRegression
lr2=LogisticRegression(max_iter=1000)
m=lr2.fit(x_train,y_train)

yp2=m.predict(x_test)
print(accuracy_score(y_test,yp2))
# Out:
# 0.9779179810725552
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
print(confusion_matrix(y_test,yp2))
# Out:
# [[2412   48]
#  [  36 1308]]

# %%
print(classification_report(y_test,yp2))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.99      0.98      0.98      2460
#            2       0.96      0.97      0.97      1344
#
#     accuracy                           0.98      3804
#    macro avg       0.97      0.98      0.98      3804
# weighted avg       0.98      0.98      0.98      3804

# %%
y.isnull().sum()
y.fillna(0,inplace=True)
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 19015    2
# 19016    2
# 19017    2
# 19018    2
# 19019    2
# Name: class, Length: 19020, dtype: int64

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier()
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
d=model.predict(x_test)
print(accuracy_score(y_test,d))
# Out:
# 0.999211356466877

# %%
knn = KNeighborsClassifier(n_neighbors=2)
knn.fit(x_train, y_train)
y_pred = knn.predict(x_test)
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 0.9981598317560463
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      2460
#            2       1.00      0.99      1.00      1344
#
#     accuracy                           1.00      3804
#    macro avg       1.00      1.00      1.00      3804
# weighted avg       1.00      1.00      1.00      3804

# %%
accuracy_scores = {}
for k in range(1, 21):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_train, y_train)
    y_pred = knn.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    accuracy_scores[k] = accuracy
    print(f'Accuracy with k={k}: {accuracy:.4f}')
# Out:
# Accuracy with k=1: 0.9992
# Accuracy with k=2: 0.9982
# Accuracy with k=3: 0.9989
# Accuracy with k=4: 0.9987
# Accuracy with k=5: 0.9992
# Accuracy with k=6: 0.9989
# Accuracy with k=7: 0.9997
# Accuracy with k=8: 0.9992
# Accuracy with k=9: 0.9995
# Accuracy with k=10: 0.9992
# Accuracy with k=11: 0.9995
# Accuracy with k=12: 0.9989
# Accuracy with k=13: 0.9987
# Accuracy with k=14: 0.9989
# Accuracy with k=15: 0.9989
# Accuracy with k=16: 0.9989
# Accuracy with k=17: 0.9989
# Accuracy with k=18: 0.9989
# Accuracy with k=19: 0.9989
# Accuracy with k=20: 0.9989

# %% [markdown]
# SMOTE

# %%
import pandas as pd
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state=42)
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)
smote = SMOTE(random_state=42)
x_train_resampled, y_train_resampled = smote.fit_resample(x_train_scaled,y_train)
print("Class distribution before SMOTE:")
print(y_train.value_counts())
print("\nClass distribution after SMOTE:")
print(pd.Series(y_train_resampled).value_counts())
# Out:
# Class distribution before SMOTE:
# class
# 1    9872
# 2    5344
# Name: count, dtype: int64
#
# Class distribution after SMOTE:
# class
# 1    9872
# 2    9872
# Name: count, dtype: int64

# %%
smote = SMOTE(random_state=42)
x_test_resampled, y_test_resampled = smote.fit_resample(x_test_scaled, y_test)
print("Class distribution before SMOTE:")
print(y_test.value_counts())
print("\nClass distribution after SMOTE:")
print(pd.Series(y_test_resampled).value_counts())
# Out:
# Class distribution before SMOTE:
# class
# 1    2460
# 2    1344
# Name: count, dtype: int64
#
# Class distribution after SMOTE:
# class
# 2    2460
# 1    2460
# Name: count, dtype: int64

# %% [markdown]
# SVM after SMOTE

# %%
from sklearn.svm import SVC
svm=SVC()
m=svm.fit(x_train_resampled,y_train_resampled)

# %%
yp=m.predict(x_test_resampled)
print(accuracy_score(y_test_resampled,yp))
# Out:
# 0.9920731707317073

# %% [markdown]
# PERCEPTRON after SMOTE

# %%
from sklearn.linear_model import Perceptron
percep=Perceptron()
m=percep.fit(x_train_resampled,y_train_resampled)

# %%
yp1=m.predict(x_test_resampled)
print(accuracy_score(y_test_resampled,yp1))
# Out:
# 0.9971544715447155

# %% [markdown]
# LOGISTIC REGRESSION after SMOTE

# %%
from sklearn.linear_model import LogisticRegression
logistic=LogisticRegression(max_iter=1000)
m=logistic.fit(x_train_resampled,y_train_resampled)

# %%
yp2=m.predict(x_test_resampled)
print(accuracy_score(y_test_resampled,yp2))
# Out:
# 0.9953252032520326

# %% [markdown]
# KNN after SMOTE

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
m=knn.fit(x_train_resampled,y_train_resampled)

# %%
d=m.predict(x_test_resampled)
print(accuracy_score(y_test_resampled,d))
# Out:
# 0.9774390243902439

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train_resampled, y_train_resampled)
y_pred = knn.predict(x_test_resampled)
print(accuracy_score(y_test_resampled,y_pred))
print(classification_report(y_test_resampled, y_pred))
# Out:
# 0.9752032520325203
#               precision    recall  f1-score   support
#
#            1       0.97      0.98      0.98      2460
#            2       0.98      0.97      0.98      2460
#
#     accuracy                           0.98      4920
#    macro avg       0.98      0.98      0.98      4920
# weighted avg       0.98      0.98      0.98      4920

# %% [markdown]
# PCA

# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
pca = PCA(n_components=10)
x_pca = pca.fit_transform(x_scaled)

# %%
print("Original shape:", x.shape)
print("PCA shape:", x_pca.shape)
# Out:
# Original shape: (19020, 11)
# PCA shape: (19020, 10)

# %%
x_pca_df = pd.DataFrame(x_pca, columns=['PC1','PC2','PC3','PC4','PC5','PC6','PC7','PC8','PC9','PC10'])
print(x_pca_df)
# Out:
#             PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0     -1.147556 -1.010732  0.449298 -0.313848 -1.663433 -0.567857 -0.920298
# 1     -1.817556 -1.312019 -1.153800 -0.374117  0.033064  0.354134 -0.843268
# 2      5.856818  0.907039  1.472308 -1.907231 -2.505954  2.681838 -4.072664
# 3     -2.686307 -0.827741 -0.989926 -0.204166 -0.949661  0.248984 -0.542009
# 4      1.508017 -1.491795 -1.547737  1.099047  0.855668  0.517533 -1.342197
# ...         ...       ...       ...       ...       ...       ...       ...
# 19015 -2.058988  0.546749  0.380103  0.100438  0.537496  0.260031  1.909297
# 19016 -1.699589  1.770410  1.470752 -0.259028  1.546529  0.509637 -0.417242
# 19017  2.885764  0.365363  1.192026 -0.575020  0.840635  0.094016  0.645570
# 19018  4.805829  2.849850  0.664173 -3.087892  0.543667  2.436892 -1.493345
# 19019  3.530580  4.637111 -1.880825  1.417193 -0.506444  0.387473  0.395071
#
#             PC8       PC9      PC10
# ...

# %% [markdown]
# Bootstrapping Logistic regression, Perceptron ,SVM and KNN

# %%
from sklearn.utils import resample
from collections import Counter
from scipy.stats import mode
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
X_test_scaled = scaler.transform(x_test)
models = {
'Logistic Regression': LogisticRegression(),
'Perceptron': Perceptron(),
'SVM': SVC(),
'KNN':KNeighborsClassifier()
}
n_bootstrap_samples = 10
model_predictions = {model_name: [] for model_name in models}
for model_name, model in models.items():
    bootstrap_preds = []
    for i in range(n_bootstrap_samples):
        x_resampled, y_resampled = resample(x_train_scaled, y_train)
        model.fit(x_resampled, y_resampled)
        y_pred = model.predict(x_test_scaled)
        bootstrap_preds.append(y_pred)
    final_preds = []
    for i in range(len(bootstrap_preds[0])):
        pred = [bootstrap_preds[j][i]
                for j in range(len(bootstrap_preds))]
        final_preds.append(Counter(pred).most_common(1)[0][0])
    model_predictions[model_name] = final_preds
for model_name, y_pred in model_predictions.items():
    print(model_name)
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Logistic Regression
# Accuracy: 0.9939537329127235
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.99      1.00      1.00      2460
#            2       0.99      0.99      0.99      1344
#
#     accuracy                           0.99      3804
#    macro avg       0.99      0.99      0.99      3804
# weighted avg       0.99      0.99      0.99      3804
#
# Perceptron
# Accuracy: 0.9965825446898002
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      2460
#            2       0.99      1.00      1.00      1344
#
#     accuracy                           1.00      3804
#    macro avg       1.00      1.00      1.00      3804
# weighted avg       1.00      1.00      1.00      3804
#
# SVM
# Accuracy: 0.9894847528916929
# Classification Report:
#                precision    recall  f1-score   support
#
# ...

# %%
import matplotlib.pyplot as plt
model_names = list(model_predictions.keys())
accuracies = [accuracy_score(y_test, y_pred) for y_pred in model_predictions.values()]
plt.figure(figsize=(10, 6))
plt.bar(model_names, accuracies, color=['red','blue','yellow','green'])
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.title('Model Accuracy Comparison')
plt.show()
